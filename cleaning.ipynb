# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Ameet Computer\OneDrive\Pictures\Camera Roll\power bi Dashboards\bannk credit risk\Customers.csv")

print(df.head)
# Out:
# <bound method NDFrame.head of     CustomerID  Age  Gender           Occupation  Income             State
# 0     CUST1000   59    Male              Teacher   44596       Balochistan
# 1     CUST1001   49  Female  Government Employee  162351       Balochistan
# 2     CUST1002   35  Female              Teacher  224269         Islamabad
# 3     CUST1003   63    Male  Government Employee  168155            Punjab
# 4     CUST1004   28  Female  Government Employee  150674         Islamabad
# ..         ...  ...     ...                  ...     ...               ...
# 495   CUST1495   46    Male  Government Employee  182360  Gilgit Baltistan
# 496   CUST1496   30  Female       Business Owner  283627             Sindh
# 497   CUST1497   46  Female              Teacher  125081            Punjab
# 498   CUST1498   54    Male  Government Employee   66877         Islamabad
# 499   CUST1499   61  Female  Government Employee  241957       Balochistan
#
# [500 rows x 6 columns]>

# %%
df.dtypes
# Out:
# CustomerID    object
# Age            int64
# Gender        object
# Occupation    object
# Income         int64
# State         object
# dtype: object

# %%
df.describe()
# Out:
#               Age         Income
# count  500.000000     500.000000
# mean    43.116000  190838.448000
# std     12.733217   91121.576777
# min     21.000000   31622.000000
# 25%     32.000000  113494.250000
# 50%     44.000000  189317.000000
# 75%     53.000000  268996.750000
# max     64.000000  349804.000000

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(" ", "")

# %%
df.isnull().sum()
# Out:
# CustomerID    0
# Age           0
# Gender        0
# Occupation    0
# Income        0
# State         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df["age"])
plt.title("Age boxplot")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.figure(figsize=(8,5))
sns.boxplot(x="age", y="income", data=df)
plt.xticks(rotation=45)
plt.title("age income distribution")
plt.show()

# %%
#see outliers
Q1 = df['income'].quantile(0.25)
Q3 = df['income'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['income'] < lower_bound) | (df['income'] > upper_bound)]

print(outliers)
# Out:
# Empty DataFrame
# Columns: [customerid, age, gender, occupation, income, state]
# Index: []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=df['income'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.select_dtypes(include='number').corr()

plt.figure(figsize=(10,6))
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()
